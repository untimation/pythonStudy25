# %% [markdown]
# <a href="https://colab.research.google.com/github/untimation/pythonStudy25/blob/master/ForExam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
names = []
ko = []
en = []
ma = []

def tag(kor, eng, math):
    tot = kor + eng + math
    avg = tot / 3
    if avg >= 90 :
        grade = "A"
    elif avg >= 80 :
        grade = "B"
    elif avg >= 70 :
        grade = "C"
    elif avg >= 60 :
        grade = "D"
    else :
        grade = "F"
    print("총합 : %d \n평균 : %.2f \n등급 : %s \n" % (tot, avg, grade))

run = True
trun = True
frun = True
name = ""
while run :
    prompt = """
    1. 성적추가
    2. 성적확인
    3. 성적수정
    4. 성적삭제
    5. 프로그램 종료

    Enter number (1~5) : """

    U = """
    1. 이름수정
    2. 국어수정
    3. 영어수정
    4. 수학수정
    5. 수정종료"""
    print(prompt)

    select = int(input("번호 입력 : "))
    if select == 1 :
        print("성적을 입력합니다. \n이름을 입력해주세요.")
        name = input("이름 : ")
        names += [name]
        print("국어 성적을 입력해주세요.")
        kor = int(input("국어 : "))
        ko += [kor]
        print("영어 성적을 입력해주세요.")
        eng = int(input("영어 : "))
        en += [eng]
        print("수학 성적을 입력해주세요.")
        math = int(input("수학 : "))
        ma += [math]
        print("이름 : %s, 국어 : %d, 영어 : %d, 수학 : %d" % (name, kor, eng, math))
        print("성적이 등록되었습니다.")
    elif select == 2 :
        print("성적을 확인합니다. \n이름을 확인합니다.")
        if name == "" :
            print("등록된 이름이 없습니다.")
        elif name == "%s" % name :
            for name, kor, eng, math, tot, avg, grade in zip(names, ko, en, ma, to, av, gr):
                print("이름 : %s \n국어 : %d \n영어 : %d \n수학 : %d \n총합 : %d \n평균 : %.2f \n등급 : %s \n"
                    % (name, kor, eng, math, tot, avg, grade))
        else :
            print("등록된 이름이 없습니다.")
    elif select == 3:
        print("성적을 수정합니다. \n이름을 확인합니다.")
        trun = True

        while trun:
            name = input("이름: ")
            if name in names:
                i = names.index(name)
                print("확인 되었습니다.")
                trun = False
                Urun = True

                while Urun:
                    print("\n1. 이름 수정\n2. 국어 수정\n3. 영어 수정\n4. 수학 수정\n5. 수정 종료")
                    U = int(input("번호를 입력해주세요: "))

                    if U == 1:
                        print("이름을 수정합니다.")
                        names[i] = input("새로운 이름: ")
                        print("이름이 수정되었습니다.")

                    elif U == 2:
                        print("국어 성적을 수정합니다.")
                        ko[i] = int(input("새로운 국어 점수: "))
                        print("국어 성적이 수정되었습니다.")

                    elif U == 3:
                        print("영어 성적을 수정합니다.")
                        en[i] = int(input("새로운 영어 점수: "))
                        print("영어 성적이 수정되었습니다.")

                    elif U == 4:
                        print("수학 성적을 수정합니다.")
                        ma[i] = int(input("새로운 수학 점수: "))
                        print("수학 성적이 수정되었습니다.")

                    elif U == 5:
                        print("수정을 종료합니다.")
                        Urun = False

                    else:
                        print("올바르지 않은 번호입니다. 다시 입력해 주세요.")

                print("\n수정된 성적:")
                print("이름: %s, 국어: %d, 영어: %d, 수학: %d" % (names[i], ko[i], en[i], ma[i]))
            else:
                print("등록된 이름이 없습니다. 다시 입력하세요.")

    elif select == 4:
        while frun:
            print("성적을 삭제합니다.\n이름을 확인합니다.")
            name = input("이름: ")

            if name in names:
                print("%s의 성적이 삭제되었습니다." % name)
                i = names.index(name)
                del names[i]
                del ko[i]
                del en[i]
                del ma[i]

                frun = False
            else:
                print("등록된 이름이 없습니다. 다시 입력하세요.")

    elif select == 5 :
        print("프로그램을 종료합니다.")
        run = False
    else :
        print("옳바르지 않은 번호입니다. \n다시 입력해 주세요.")
for name, kor, eng, math in zip(names, ko, en, ma):
    print("이름: %s \n국어: %d \n영어: %d \n수학: %d" % (name, kor, eng, math))
    tag(kor, eng, math)
# Out:
#     1. 성적추가
#     2. 성적확인
#     3. 성적수정
#     4. 성적삭제
#     5. 프로그램 종료
#
#     Enter number (1~5) :
# 번호 입력 : 1
# 성적을 입력합니다.
# 이름을 입력해주세요.
# 이름 : a
# 국어 성적을 입력해주세요.
# 국어 : 35
# 영어 성적을 입력해주세요.
# 영어 : 46
# 수학 성적을 입력해주세요.
# 수학 : 57
# 이름 : a, 국어 : 35, 영어 : 46, 수학 : 57
# 성적이 등록되었습니다.
#
#     1. 성적추가
#     2. 성적확인
#     3. 성적수정
#     4. 성적삭제
#     5. 프로그램 종료
#
#     Enter number (1~5) :
# 번호 입력 : 1
# 성적을 입력합니다.
# 이름을 입력해주세요.
# 이름 : b
# 국어 성적을 입력해주세요.
# 국어 : 26
# 영어 성적을 입력해주세요.
# 영어 : 84
# 수학 성적을 입력해주세요.
# 수학 : 99
# 이름 : b, 국어 : 26, 영어 : 84, 수학 : 99
# 성적이 등록되었습니다.
#
#     1. 성적추가
#     2. 성적확인
#     3. 성적수정
#     4. 성적삭제
#     5. 프로그램 종료
#
#     Enter number (1~5) :
# 번호 입력 : 5
# 프로그램을 종료합니다.
# 이름: a
# 국어: 35
# 영어: 46
# 수학: 57
# 총합 : 138
# 평균 : 46.00
# 등급 : F
#
# 이름: b
# 국어: 26
# 영어: 84
# 수학: 99
# 총합 : 209
# 평균 : 69.67
# 등급 : D
